# %% [markdown]
# # ART Boundary Attack

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import sys
#!{sys.executable} -m pip install git+https://github.com/nottombrown/imagenet_stubs
sys.path.append("..")

# %matplotlib inline

import imagenet_stubs
import numpy as np
from keras.preprocessing import image
from keras.applications.resnet50 import ResNet50, preprocess_input
from matplotlib import pyplot as plt
from IPython.display import clear_output

from art.classifiers import KerasClassifier
from art.attacks import BoundaryAttack
from art.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Model Definition

# %%
mean_imagenet = np.zeros([224, 224,3])
mean_imagenet[...,0].fill(103.939)
mean_imagenet[...,1].fill(116.779)
mean_imagenet[...,2].fill(123.68)
model = ResNet50(weights='imagenet')
classifier = KerasClassifier(clip_values=(0, 255), model=model, preprocessing=(mean_imagenet, 1))

# %% [markdown]
# # Get Target and Init Images

# %%
target_image_name = 'koala.jpg'
init_image_name = 'tractor.jpg'
for image_path in imagenet_stubs.get_image_paths():
    if image_path.endswith(target_image_name):
        target_image = image.load_img(image_path, target_size=(224, 224))
        target_image = image.img_to_array(target_image)
    if image_path.endswith(init_image_name):
        init_image = image.load_img(image_path, target_size=(224, 224))
        init_image = image.img_to_array(init_image)

print("Target image is: ", np.argmax(classifier.predict(np.array([target_image]))[0]))
plt.imshow(target_image.astype(np.uint))
plt.show()
print("Init image is: ", np.argmax(classifier.predict(np.array([init_image]))[0]))
plt.imshow(init_image.astype(np.uint))
plt.show()
# Out:
# Target image is:  105
# Init image is:  866

# %% [markdown]
# # Boundary Targeted Attack

# %%
attack = BoundaryAttack(classifier=classifier, targeted=True, max_iter=0, num_trial=25, 
                        sample_size=20, delta=0.01, step_adapt=2.0/3, epsilon=0.01)
attack.init_image = init_image

for i in range(50):
    x_adv = attack.generate(np.array([target_image]), y=to_categorical([866], 1000))

    #clear_output()
    print("Adversarial image at step %d:" % (i * 20), "L2 error: ", 
          np.linalg.norm(np.reshape(x_adv[0] - target_image, [-1])),
          "Class label: ", np.argmax(classifier.predict(x_adv)[0]))
    plt.imshow(x_adv[0].astype(np.uint))
    plt.show(block=False)
    
    attack.max_iter = 20
    attack.init_image = x_adv[0]
    attack.delta = attack.curr_delta
    attack.epsilon = attack.curr_epsilon
# Out:
# Adversarial image at step 0: L2 error:  44399.297 Class label:  866
# loop success 0.015000 1.000000
# loop success 0.022500 1.000000
# loop success 0.033750 1.000000
# loop success 0.050625 1.000000
# loop success 0.075938 1.000000
# loop success 0.113906 1.000000
# loop success 0.170859 1.000000
# loop success 0.256289 1.000000
# loop success 0.384434 1.000000
# loop success 0.256289 0.200000
# loop success 0.075938 0.050000
# loop success 0.050625 0.150000
# loop success 0.050625 0.250000
# loop success 0.050625 0.350000
# loop success 0.075938 0.550000
# loop success 0.075938 0.450000
# loop success 0.050625 0.150000
# loop success 0.075938 0.550000
# loop success 0.050625 0.100000
# loop success 0.050625 0.200000
# Adversarial image at step 20: L2 error:  22356.521 Class label:  866
# loop success 0.033750 0.050000
# loop success 0.050625 0.700000
# loop success 0.033750 0.100000
# loop success 0.033750 0.350000
# loop success 0.033750 0.300000
# loop success 0.022500 0.150000
# loop success 0.022500 0.500000
# loop success 0.022500 0.450000
# loop success 0.033750 0.700000
# loop success 0.033750 0.400000
# loop success 0.050625 0.550000
# loop success 0.050625 0.300000
# loop success 0.033750 0.100000
# loop success 0.033750 0.250000
# loop success 0.033750 0.200000
# loop success 0.033750 0.350000
# loop success 0.033750 0.250000
# loop success 0.033750 0.300000
# loop success 0.033750 0.300000
# loop success 0.033750 0.200000
# Adversarial image at step 40: L2 error:  21360.148 Class label:  866
# loop success 0.033750 0.500000
# loop success 0.033750 0.450000
# loop success 0.033750 0.450000
# loop success 0.022500 0.100000
# loop success 0.022500 0.250000
# loop success 0.022500 0.450000
# loop success 0.022500 0.450000
# loop success 0.022500 0.200000
# loop success 0.022500 0.200000
# loop success 0.022500 0.300000
# loop success 0.033750 0.950000
# loop success 0.033750 0.400000
# loop success 0.022500 0.050000
# loop success 0.022500 0.350000
# loop success 0.033750 0.700000
# loop success 0.033750 0.200000
# loop success 0.015000 0.100000
# loop success 0.015000 0.200000
# loop success 0.015000 0.300000
# loop success 0.015000 0.400000
# Adversarial image at step 60: L2 error:  21175.77 Class label:  866
# loop success 0.022500 0.850000
# loop success 0.022500 0.450000
# loop success 0.033750 0.800000
# loop success 0.050625 0.550000
# loop success 0.050625 0.250000
# loop success 0.033750 0.050000
# loop success 0.033750 0.400000
# loop success 0.033750 0.200000
# loop success 0.033750 0.250000
# loop success 0.022500 0.050000
# loop success 0.022500 0.250000
# loop success 0.022500 0.200000
# loop success 0.022500 0.450000
# loop success 0.015000 0.100000
# loop success 0.010000 0.150000
# loop success 0.006667 0.100000
# loop success 0.004444 0.100000
# loop success 0.002963 0.100000
# loop success 0.002963 0.300000
# loop success 0.002963 0.500000
# Adversarial image at step 80: L2 error:  20583.227 Class label:  866
# loop success 0.002963 0.300000
# loop success 0.004444 0.800000
# loop success 0.004444 0.400000
# loop success 0.004444 0.500000
# loop success 0.004444 0.500000
# loop success 0.006667 0.750000
# loop success 0.006667 0.350000
# loop success 0.006667 0.250000
# loop success 0.006667 0.200000
# loop success 0.006667 0.300000
# loop success 0.010000 0.550000
# loop success 0.010000 0.250000
# loop success 0.010000 0.350000
# loop success 0.010000 0.250000
# loop success 0.010000 0.400000
# loop success 0.006667 0.050000
# loop success 0.006667 0.450000
# loop success 0.006667 0.300000
# loop success 0.006667 0.350000
# loop success 0.006667 0.200000
# Adversarial image at step 100: L2 error:  20330.932 Class label:  866
# loop success 0.006667 0.350000
# loop success 0.006667 0.350000
# loop success 0.006667 0.350000
# loop success 0.010000 0.700000
# loop success 0.010000 0.250000
# loop success 0.015000 0.550000
# loop success 0.022500 0.550000
# loop success 0.015000 0.150000
# loop success 0.015000 0.300000
# loop success 0.022500 0.850000
# loop success 0.022500 0.300000
# loop success 0.022500 0.250000
# loop success 0.015000 0.050000
# loop success 0.015000 0.450000
# loop success 0.015000 0.350000
# loop success 0.015000 0.250000
# loop success 0.022500 0.550000
# loop success 0.015000 0.150000
# loop success 0.015000 0.500000
# loop success 0.015000 0.400000
# Adversarial image at step 120: L2 error:  20021.32 Class label:  866
# loop success 0.015000 0.400000
# loop success 0.015000 0.300000
# loop success 0.010000 0.150000
# loop success 0.010000 0.500000
# loop success 0.010000 0.300000
# loop success 0.010000 0.300000
# loop success 0.010000 0.250000
# loop success 0.010000 0.350000
# loop success 0.010000 0.200000
# loop success 0.010000 0.400000
# loop success 0.015000 1.000000
# loop success 0.015000 0.250000
# loop success 0.015000 0.200000
# loop success 0.015000 0.400000
# loop success 0.015000 0.350000
# loop success 0.015000 0.350000
# loop success 0.015000 0.250000
# loop success 0.022500 0.550000
# loop success 0.033750 0.550000
# loop success 0.022500 0.100000
# Adversarial image at step 140: L2 error:  19537.816 Class label:  866
# loop success 0.022500 0.250000
# loop success 0.015000 0.100000
# loop success 0.022500 0.650000
# loop success 0.022500 0.350000
# loop success 0.015000 0.100000
# loop success 0.015000 0.500000
# loop success 0.015000 0.300000
# loop success 0.015000 0.200000
# loop success 0.010000 0.150000
# loop success 0.015000 0.850000
# loop success 0.015000 0.250000
# loop success 0.015000 0.200000
# loop success 0.015000 0.200000
# loop success 0.010000 0.150000
# loop success 0.015000 0.700000
# loop success 0.022500 0.700000
# loop success 0.015000 0.100000
# loop success 0.015000 0.350000
# loop success 0.015000 0.250000
# loop success 0.015000 0.250000
# Adversarial image at step 160: L2 error:  19464.08 Class label:  866
# loop success 0.015000 0.500000
# loop success 0.022500 0.600000
# loop success 0.033750 0.600000
# loop success 0.022500 0.150000
# loop success 0.015000 0.150000
# loop success 0.022500 0.550000
# loop success 0.015000 0.150000
# loop success 0.015000 0.250000
# loop success 0.015000 0.300000
# loop success 0.015000 0.350000
# loop success 0.015000 0.250000
# loop success 0.015000 0.400000
# loop success 0.015000 0.450000
# loop success 0.015000 0.350000
# loop success 0.010000 0.150000
# loop success 0.010000 0.500000
# loop success 0.010000 0.300000
# loop success 0.010000 0.200000
# loop success 0.015000 0.800000
# loop success 0.010000 0.150000
# Adversarial image at step 180: L2 error:  19249.37 Class label:  866
# loop success 0.015000 0.700000
# loop success 0.022500 0.950000
# loop success 0.022500 0.200000
# loop success 0.015000 0.100000
# loop success 0.022500 0.550000
# loop success 0.022500 0.250000
# loop success 0.033750 0.950000
# loop success 0.033750 0.200000
# loop success 0.033750 0.500000
# loop success 0.033750 0.250000
# loop success 0.033750 0.200000
# loop success 0.033750 0.250000
# loop success 0.015000 0.100000
# loop success 0.015000 0.250000
# loop success 0.015000 0.250000
# loop success 0.022500 0.550000
# loop success 0.022500 0.250000
# loop success 0.022500 0.500000
# loop success 0.022500 0.500000
# loop success 0.022500 0.350000
# Adversarial image at step 200: L2 error:  18836.877 Class label:  866
# loop success 0.033750 0.800000
# loop success 0.033750 0.400000
# loop success 0.033750 0.300000
# loop success 0.033750 0.200000
# loop success 0.033750 0.200000
# loop success 0.033750 0.250000
# loop success 0.022500 0.200000
# loop success 0.022500 0.500000
# loop success 0.022500 0.250000
# loop success 0.033750 0.600000
# loop success 0.033750 0.450000
# loop success 0.033750 0.300000
# loop success 0.022500 0.100000
# loop success 0.033750 0.800000
# loop success 0.022500 0.050000
# loop success 0.022500 0.300000
# loop success 0.022500 0.200000
# loop success 0.022500 0.500000
# loop success 0.022500 0.350000
# loop success 0.015000 0.150000
# Adversarial image at step 220: L2 error:  18455.482 Class label:  866
# loop success 0.022500 0.750000
# loop success 0.015000 0.150000
# loop success 0.015000 0.400000
# loop success 0.015000 0.350000
# loop success 0.022500 0.550000
# loop success 0.022500 0.200000
# loop success 0.033750 0.750000
# loop success 0.033750 0.300000
# loop success 0.033750 0.250000
# loop success 0.022500 0.150000
# loop success 0.033750 0.800000
# loop success 0.033750 0.200000
# loop success 0.022500 0.050000
# loop success 0.033750 0.750000
# loop success 0.033750 0.250000
# loop success 0.022500 0.150000
# loop success 0.015000 0.100000
# loop success 0.022500 0.600000
# loop success 0.022500 0.200000
# loop success 0.022500 0.250000
# Adversarial image at step 240: L2 error:  18280.012 Class label:  866
# loop success 0.022500 0.200000
# loop success 0.022500 0.350000
# loop success 0.022500 0.300000
# loop success 0.015000 0.150000
# loop success 0.015000 0.500000
# loop success 0.015000 0.350000
# loop success 0.015000 0.350000
# loop success 0.022500 0.700000
# loop success 0.022500 0.200000
# loop success 0.022500 0.450000
# loop success 0.022500 0.200000
# loop success 0.022500 0.300000
# loop success 0.022500 0.200000
# loop success 0.015000 0.100000
# loop success 0.015000 0.300000
# loop success 0.022500 0.650000
# loop success 0.022500 0.350000
# loop success 0.022500 0.400000
# loop success 0.022500 0.250000
# loop success 0.022500 0.400000
# Adversarial image at step 260: L2 error:  18092.07 Class label:  866
# loop success 0.015000 0.100000
# loop success 0.015000 0.200000
# loop success 0.015000 0.250000
# loop success 0.015000 0.250000
# loop success 0.015000 0.250000
# loop success 0.015000 0.250000
# loop success 0.022500 0.750000
# loop success 0.022500 0.450000
# loop success 0.022500 0.500000
# loop success 0.022500 0.450000
# loop success 0.033750 0.800000
# loop success 0.033750 0.250000
# loop success 0.022500 0.150000
# loop success 0.022500 0.250000
# loop success 0.022500 0.300000
# loop success 0.022500 0.250000
# loop success 0.022500 0.300000
# loop success 0.022500 0.350000
# loop success 0.022500 0.400000
# loop success 0.033750 0.850000
# Adversarial image at step 280: L2 error:  17796.516 Class label:  866
# loop success 0.033750 0.300000
# loop success 0.022500 0.150000
# loop success 0.022500 0.200000
# loop success 0.015000 0.050000
# loop success 0.010000 0.100000
# loop success 0.010000 0.500000
# loop success 0.010000 0.400000
# loop success 0.010000 0.300000
# loop success 0.010000 0.450000
# loop success 0.010000 0.350000
# loop success 0.010000 0.500000
# loop success 0.015000 0.750000
# loop success 0.010000 0.150000
# loop success 0.006667 0.100000
# loop success 0.006667 0.400000
# loop success 0.004444 0.150000
# loop success 0.004444 0.250000
# loop success 0.004444 0.450000
# loop success 0.006667 0.600000
# loop success 0.006667 0.250000
# Adversarial image at step 300: L2 error:  17540.066 Class label:  866
# loop success 0.006667 0.350000
# loop success 0.006667 0.200000
# loop success 0.010000 0.550000
# loop success 0.015000 0.550000
# loop success 0.015000 0.450000
# loop success 0.015000 0.300000
# loop success 0.015000 0.350000
# loop success 0.015000 0.250000
# loop success 0.022500 0.850000
# loop success 0.022500 0.400000
# loop success 0.033750 0.550000
# loop success 0.033750 0.250000
# loop success 0.033750 0.400000
# loop success 0.022500 0.100000
# loop success 0.033750 0.700000
# loop success 0.015000 0.150000
# loop success 0.010000 0.150000
# loop success 0.015000 0.700000
# loop success 0.015000 0.400000
# loop success 0.010000 0.150000
# Adversarial image at step 320: L2 error:  17351.467 Class label:  866
# loop success 0.015000 0.550000
# loop success 0.010000 0.350000
# loop success 0.015000 0.550000
# loop success 0.015000 0.350000
# loop success 0.015000 0.300000
# loop success 0.010000 0.150000
# loop success 0.010000 0.500000
# loop success 0.010000 0.350000
# loop success 0.010000 0.300000
# loop success 0.010000 0.400000
# loop success 0.015000 0.850000
# loop success 0.022500 0.650000
# loop success 0.022500 0.250000
# loop success 0.015000 0.100000
# loop success 0.010000 0.400000
# loop success 0.010000 0.350000
# loop success 0.010000 0.350000
# loop success 0.010000 0.200000
# loop success 0.010000 0.350000
# loop success 0.010000 0.350000
# Adversarial image at step 340: L2 error:  16978.48 Class label:  866
# loop success 0.010000 0.300000
# loop success 0.010000 0.350000
# loop success 0.015000 0.950000
# loop success 0.022500 0.700000
# loop success 0.015000 0.100000
# loop success 0.015000 0.400000
# loop success 0.015000 0.500000
# loop success 0.015000 0.350000
# loop success 0.022500 0.550000
# loop success 0.015000 0.150000
# loop success 0.015000 0.300000
# loop success 0.015000 0.300000
# loop success 0.015000 0.300000
# loop success 0.010000 0.050000
# loop success 0.015000 0.800000
# loop success 0.015000 0.300000
# loop success 0.015000 0.300000
# loop success 0.015000 0.400000
# loop success 0.015000 0.400000
# loop success 0.015000 0.350000
# Adversarial image at step 360: L2 error:  16761.115 Class label:  866
# loop success 0.015000 0.500000
# loop success 0.015000 0.200000
# loop success 0.015000 0.200000
# loop success 0.015000 0.450000
# loop success 0.015000 0.300000
# loop success 0.015000 0.500000
# loop success 0.015000 0.350000
# loop success 0.015000 0.500000
# loop success 0.010000 0.050000
# loop success 0.010000 0.300000
# loop success 0.010000 0.300000
# loop success 0.010000 0.300000
# loop success 0.010000 0.450000
# loop success 0.015000 0.550000
# loop success 0.015000 0.300000
# loop success 0.022500 0.600000
# loop success 0.033750 0.550000
# loop success 0.022500 0.100000
# loop success 0.022500 0.350000
# loop success 0.015000 0.150000
# Adversarial image at step 380: L2 error:  16464.643 Class label:  866
# loop success 0.022500 0.800000
# loop success 0.033750 0.600000
# loop success 0.015000 0.100000
# loop success 0.022500 0.900000
# loop success 0.022500 0.350000
# loop success 0.022500 0.300000
# loop success 0.015000 0.150000
# loop success 0.015000 0.350000
# loop success 0.015000 0.500000
# loop success 0.010000 0.100000
# loop success 0.015000 0.650000
# loop success 0.010000 0.100000
# loop success 0.015000 0.550000
# loop success 0.015000 0.300000
# loop success 0.015000 0.450000
# loop success 0.015000 0.350000
# loop success 0.015000 0.300000
# loop success 0.010000 0.100000
# loop success 0.010000 0.400000
# loop success 0.010000 0.500000
# Adversarial image at step 400: L2 error:  16316.984 Class label:  866
# loop success 0.010000 0.350000
# loop success 0.010000 0.400000
# loop success 0.015000 0.550000
# loop success 0.015000 0.400000
# loop success 0.022500 1.000000
# loop success 0.022500 0.350000
# loop success 0.022500 0.350000
# loop success 0.015000 0.150000
# loop success 0.022500 0.600000
# loop success 0.022500 0.300000
# loop success 0.022500 0.250000
# loop success 0.022500 0.200000
# loop success 0.022500 0.500000
# loop success 0.015000 0.150000
# loop success 0.015000 0.500000
# loop success 0.015000 0.450000
# loop success 0.015000 0.250000
# loop success 0.022500 0.600000
# loop success 0.022500 0.300000
# loop success 0.033750 0.650000
# Adversarial image at step 420: L2 error:  16280.891 Class label:  866
# loop success 0.022500 0.150000
# loop success 0.022500 0.200000
# loop success 0.022500 0.500000
# loop success 0.015000 0.150000
# loop success 0.022500 0.750000
# loop success 0.033750 0.900000
# loop success 0.033750 0.400000
# loop success 0.022500 0.050000
# loop success 0.033750 0.850000
# loop success 0.022500 0.100000
# loop success 0.033750 0.800000
# loop success 0.022500 0.100000
# loop success 0.033750 0.600000
# loop success 0.033750 0.300000
# loop success 0.033750 0.450000
# loop success 0.022500 0.100000
# loop success 0.022500 0.450000
# loop success 0.015000 0.100000
# loop success 0.022500 0.750000
# loop success 0.022500 0.500000
# Adversarial image at step 440: L2 error:  15989.081 Class label:  866
# loop success 0.022500 0.250000
# loop success 0.022500 0.250000
# loop success 0.033750 0.950000
# loop success 0.050625 0.600000
# loop success 0.033750 0.100000
# loop success 0.033750 0.400000
# loop success 0.050625 0.750000
# loop success 0.050625 0.250000
# loop success 0.033750 0.100000
# loop success 0.022500 0.100000
# loop success 0.022500 0.300000
# loop success 0.022500 0.450000
# loop success 0.033750 0.700000
# loop success 0.022500 0.100000
# loop success 0.033750 0.550000
# loop success 0.033750 0.250000
# loop success 0.022500 0.100000
# loop success 0.022500 0.300000
# loop success 0.022500 0.350000
# loop success 0.022500 0.200000
# Adversarial image at step 460: L2 error:  15929.868 Class label:  866
# loop success 0.033750 0.600000
# loop success 0.033750 0.200000
# loop success 0.033750 0.350000
# loop success 0.033750 0.400000
# loop success 0.022500 0.100000
# loop success 0.022500 0.450000
# loop success 0.033750 0.700000
# loop success 0.033750 0.350000
# loop success 0.033750 0.200000
# loop success 0.033750 0.300000
# loop success 0.022500 0.150000
# loop success 0.015000 0.150000
# loop success 0.010000 0.100000
# loop success 0.015000 0.550000
# loop success 0.015000 0.300000
# loop success 0.015000 0.450000
# loop success 0.022500 0.600000
# loop success 0.022500 0.400000
# loop success 0.022500 0.350000
# loop success 0.015000 0.100000
# Adversarial image at step 480: L2 error:  15557.537 Class label:  866
# loop success 0.010000 0.150000
# loop success 0.015000 0.550000
# loop success 0.015000 0.250000
# loop success 0.015000 0.450000
# loop success 0.015000 0.350000
# loop success 0.022500 0.850000
# loop success 0.022500 0.300000
# loop success 0.015000 0.100000
# loop success 0.015000 0.300000
# loop success 0.015000 0.300000
# loop success 0.015000 0.500000
# loop success 0.015000 0.500000
# loop success 0.022500 0.900000
# loop success 0.033750 0.850000
# loop success 0.033750 0.200000
# loop success 0.033750 0.200000
# loop success 0.033750 0.200000
# loop success 0.022500 0.100000
# loop success 0.033750 0.950000
# loop success 0.022500 0.150000
# Adversarial image at step 500: L2 error:  15434.838 Class label:  866
# loop success 0.022500 0.400000
# loop success 0.022500 0.250000
# loop success 0.022500 0.300000
# loop success 0.015000 0.150000
# loop success 0.015000 0.500000
# loop success 0.015000 0.350000
# loop success 0.022500 0.550000
# loop success 0.022500 0.350000
# loop success 0.022500 0.300000
# loop success 0.022500 0.250000
# loop success 0.022500 0.200000
# loop success 0.015000 0.050000
# loop success 0.015000 0.200000
# loop success 0.015000 0.200000
# loop success 0.015000 0.300000
# loop success 0.022500 0.550000
# loop success 0.022500 0.200000
# loop success 0.033750 0.650000
# loop success 0.022500 0.300000
# loop success 0.022500 0.300000
# Adversarial image at step 520: L2 error:  15329.032 Class label:  866
# loop success 0.015000 0.100000
# loop success 0.015000 0.200000
# loop success 0.015000 0.350000
# loop success 0.015000 0.200000
# loop success 0.015000 0.350000
# loop success 0.015000 0.400000
# loop success 0.015000 0.450000
# loop success 0.015000 0.450000
# loop success 0.015000 0.300000
# loop success 0.015000 0.450000
# loop success 0.022500 0.750000
# loop success 0.022500 0.200000
# loop success 0.022500 0.450000
# loop success 0.033750 0.550000
# loop success 0.022500 0.300000
# loop success 0.022500 0.350000
# loop success 0.022500 0.450000
# loop success 0.022500 0.300000
# loop success 0.033750 0.550000
# loop success 0.033750 0.300000
# Adversarial image at step 540: L2 error:  15244.209 Class label:  866
# loop success 0.022500 0.350000
# loop success 0.022500 0.300000
# loop success 0.015000 0.150000
# loop success 0.022500 0.550000
# loop success 0.015000 0.400000
# loop success 0.010000 0.150000
# loop success 0.015000 0.550000
# loop success 0.015000 0.250000
# loop success 0.015000 0.250000
# loop success 0.015000 0.350000
# loop success 0.015000 0.200000
# loop success 0.010000 0.100000
# loop success 0.010000 0.400000
# loop success 0.010000 0.450000
# loop success 0.015000 0.550000
# loop success 0.015000 0.200000
# loop success 0.010000 0.150000
# loop success 0.015000 0.700000
# loop success 0.010000 0.150000
# loop success 0.015000 0.700000
# Adversarial image at step 560: L2 error:  15037.917 Class label:  866
# loop success 0.015000 0.300000
# loop success 0.015000 0.300000
# loop success 0.015000 0.350000
# loop success 0.022500 0.600000
# loop success 0.022500 0.400000
# loop success 0.033750 0.850000
# loop success 0.022500 0.150000
# loop success 0.022500 0.250000
# loop success 0.022500 0.200000
# loop success 0.022500 0.350000
# loop success 0.022500 0.250000
# loop success 0.015000 0.150000
# loop success 0.022500 0.550000
# loop success 0.022500 0.400000
# loop success 0.022500 0.400000
# loop success 0.033750 0.550000
# loop success 0.022500 0.050000
# loop success 0.022500 0.250000
# loop success 0.033750 0.850000
# loop success 0.033750 0.300000
# Adversarial image at step 580: L2 error:  14858.167 Class label:  866
# loop success 0.033750 0.300000
# loop success 0.033750 0.300000
# loop success 0.033750 0.500000
# loop success 0.033750 0.350000
# loop success 0.022500 0.100000
# loop success 0.033750 1.000000
# loop success 0.022500 0.150000
# loop success 0.022500 0.250000
# loop success 0.033750 0.750000
# loop success 0.022500 0.150000
# loop success 0.015000 0.250000
# loop success 0.015000 0.500000
# loop success 0.022500 0.600000
# loop success 0.022500 0.250000
# loop success 0.022500 0.500000
# loop success 0.022500 0.250000
# loop success 0.015000 0.150000
# loop success 0.015000 0.350000
# loop success 0.015000 0.300000
# loop success 0.010000 0.100000
# Adversarial image at step 600: L2 error:  14834.903 Class label:  866
# loop success 0.015000 0.750000
# loop success 0.022500 0.700000
# loop success 0.022500 0.400000
# loop success 0.022500 0.350000
# loop success 0.015000 0.100000
# loop success 0.022500 1.000000
# loop success 0.033750 0.550000
# loop success 0.022500 0.100000
# loop success 0.022500 0.250000
# loop success 0.033750 0.650000
# loop success 0.033750 0.300000
# loop success 0.033750 0.400000
# loop success 0.033750 0.250000
# loop success 0.022500 0.050000
# loop success 0.033750 0.800000
# loop success 0.033750 0.300000
# loop success 0.022500 0.150000
# loop success 0.022500 0.450000
# loop success 0.033750 0.900000
# loop success 0.022500 0.150000
# Adversarial image at step 620: L2 error:  14561.734 Class label:  866
# loop success 0.015000 0.150000
# loop success 0.022500 1.000000
# loop success 0.022500 0.400000
# loop success 0.033750 0.850000
# loop success 0.050625 0.700000
# loop success 0.050625 0.300000
# loop success 0.033750 0.050000
# loop success 0.033750 0.500000
# loop success 0.033750 0.450000
# loop success 0.022500 0.150000
# loop success 0.033750 0.650000
# loop success 0.050625 0.800000
# loop success 0.050625 0.250000
# loop success 0.050625 0.200000
# loop success 0.050625 0.250000
# loop success 0.050625 0.350000
# loop success 0.033750 0.100000
# loop success 0.033750 0.350000
# loop success 0.033750 0.400000
# loop success 0.033750 0.400000
# Adversarial image at step 640: L2 error:  14619.87 Class label:  866
# loop success 0.033750 0.400000
# loop success 0.033750 0.350000
# loop success 0.022500 0.150000
# loop success 0.022500 0.250000
# loop success 0.015000 0.150000
# loop success 0.015000 0.300000
# loop success 0.022500 0.550000
# loop success 0.015000 0.150000
# loop success 0.015000 0.500000
# loop success 0.015000 0.450000
# loop success 0.015000 0.450000
# loop success 0.015000 0.300000
# loop success 0.015000 0.250000
# loop success 0.015000 0.500000
# loop success 0.015000 0.500000
# loop success 0.022500 0.700000
# loop success 0.022500 0.250000
# loop success 0.033750 0.650000
# loop success 0.033750 0.350000
# loop success 0.050625 0.550000
# Adversarial image at step 660: L2 error:  14395.513 Class label:  866
# loop success 0.050625 0.200000
# loop success 0.050625 0.350000
# loop success 0.075938 0.550000
# loop success 0.050625 0.050000
# loop success 0.050625 0.350000
# loop success 0.033750 0.150000
# loop success 0.033750 0.250000
# loop success 0.033750 0.200000
# loop success 0.033750 0.250000
# loop success 0.033750 0.450000
# loop success 0.050625 0.750000
# loop success 0.033750 0.150000
# loop success 0.050625 0.700000
# loop success 0.075938 0.600000
# loop success 0.050625 0.050000
# loop success 0.050625 0.400000
# loop success 0.033750 0.100000
# loop success 0.022500 0.050000
# loop success 0.022500 0.400000
# loop success 0.033750 0.600000
# Adversarial image at step 680: L2 error:  14382.917 Class label:  866
# loop success 0.033750 0.400000
# loop success 0.033750 0.350000
# loop success 0.033750 0.300000
# loop success 0.022500 0.100000
# loop success 0.033750 0.650000
# loop success 0.033750 0.450000
# loop success 0.033750 0.350000
# loop success 0.050625 0.550000
# loop success 0.050625 0.250000
# loop success 0.075938 0.800000
# loop success 0.050625 0.150000
# loop success 0.033750 0.150000
# loop success 0.033750 0.250000
# loop success 0.050625 0.550000
# loop success 0.033750 0.050000
# loop success 0.033750 0.400000
# loop success 0.050625 0.550000
# loop success 0.050625 0.200000
# loop success 0.050625 0.300000
# loop success 0.033750 0.150000
# Adversarial image at step 700: L2 error:  13848.777 Class label:  866
# loop success 0.022500 0.100000
# loop success 0.022500 0.300000
# loop success 0.022500 0.350000
# loop success 0.015000 0.150000
# loop success 0.015000 0.500000
# loop success 0.015000 0.350000
# loop success 0.022500 0.800000
# loop success 0.033750 0.650000
# loop success 0.022500 0.100000
# loop success 0.033750 0.800000
# loop success 0.050625 0.800000
# loop success 0.050625 0.300000
# loop success 0.050625 0.250000
# loop success 0.050625 0.350000
# loop success 0.033750 0.050000
# loop success 0.033750 0.300000
# loop success 0.033750 0.300000
# loop success 0.022500 0.150000
# loop success 0.033750 0.650000
# loop success 0.033750 0.200000
# Adversarial image at step 720: L2 error:  13859.428 Class label:  866
# loop success 0.033750 0.350000
# loop success 0.033750 0.400000
# loop success 0.050625 0.600000
# loop success 0.033750 0.050000
# loop success 0.050625 0.650000
# loop success 0.033750 0.050000
# loop success 0.033750 0.450000
# loop success 0.033750 0.400000
# loop success 0.033750 0.450000
# loop success 0.022500 0.100000
# loop success 0.022500 0.500000
# loop success 0.033750 0.650000
# loop success 0.033750 0.300000
# loop success 0.033750 0.500000
# loop success 0.033750 0.450000
# loop success 0.050625 0.550000
# loop success 0.050625 0.250000
# loop success 0.075938 0.550000
# loop success 0.075938 0.250000
# loop success 0.075938 0.250000
# Adversarial image at step 740: L2 error:  13512.296 Class label:  866
# loop success 0.050625 0.100000
# loop success 0.033750 0.100000
# loop success 0.033750 0.350000
# loop success 0.050625 1.000000
# loop success 0.075938 0.600000
# loop success 0.050625 0.050000
# loop success 0.050625 0.300000
# loop success 0.050625 0.350000
# loop success 0.022500 0.050000
# loop success 0.010000 0.050000
# loop success 0.015000 0.750000
# loop success 0.022500 0.550000
# loop success 0.033750 0.650000
# loop success 0.033750 0.350000
# loop success 0.033750 0.200000
# loop success 0.033750 0.350000
# loop success 0.050625 0.650000
# loop success 0.033750 0.100000
# loop success 0.022500 0.050000
# loop success 0.022500 0.300000
# Adversarial image at step 760: L2 error:  13207.874 Class label:  866
# loop success 0.033750 0.550000
# loop success 0.022500 0.150000
# loop success 0.022500 0.200000
# loop success 0.022500 0.200000
# loop success 0.033750 0.600000
# loop success 0.050625 0.650000
# loop success 0.050625 0.250000
# loop success 0.033750 0.100000
# loop success 0.033750 0.450000
# loop success 0.033750 0.350000
# loop success 0.022500 0.150000
# loop success 0.033750 0.750000
# loop success 0.033750 0.250000
# loop success 0.033750 0.350000
# loop success 0.022500 0.150000
# loop success 0.033750 1.000000
# loop success 0.033750 0.200000
# loop success 0.022500 0.150000
# loop success 0.022500 0.250000
# loop success 0.022500 0.400000
# Adversarial image at step 780: L2 error:  12461.054 Class label:  866
# loop success 0.022500 0.250000
# loop success 0.022500 0.400000
# loop success 0.022500 0.300000
# loop success 0.033750 1.000000
# loop success 0.050625 1.000000
# loop success 0.033750 0.100000
# loop success 0.033750 0.350000
# loop success 0.050625 0.700000
# loop success 0.050625 0.350000
# loop success 0.050625 0.200000
# loop success 0.033750 0.200000
# loop success 0.033750 0.450000
# loop success 0.033750 0.300000
# loop success 0.033750 0.250000
# loop success 0.033750 0.500000
# loop success 0.033750 0.250000
# loop success 0.022500 0.150000

# %% [markdown]
# # Boundary Untargeted Attack

# %%
attack = BoundaryAttack(classifier=classifier, targeted=False, max_iter=0, num_trial=25, 
                        sample_size=20, delta=0.01, step_adapt=2.0/3, epsilon=0.01)
for i in range(50):
    x_adv = attack.generate(np.array([target_image]))

    clear_output()
    print("Adversarial image at step %d:" % (i * 20), "L2 error: ", 
          np.linalg.norm(np.reshape(x_adv[0] - target_image, [-1])),
          "Class label: ", np.argmax(classifier.predict(x_adv)[0]))
    plt.imshow(x_adv[0].astype(np.uint))
    plt.show(block=False)
    
    attack.max_iter = 20 
    attack.init_image = x_adv[0]
    attack.delta = attack.curr_delta
    attack.epsilon = attack.curr_epsilon
# Out:
# Adversarial image at step 60: L2 error:  42981.4 Class label:  489
# loop success 0.000000 1.000000
# loop success 0.000000 1.000000
# loop success 0.000000 1.000000
# loop success 0.000000 1.000000
# loop success 0.000000 1.000000
# loop success 0.000000 1.000000
# loop success 0.000000 1.000000
# loop success 0.000000 1.000000
# loop success 0.000000 1.000000
# loop success 0.000000 1.000000
# loop success 0.000000 1.000000
# loop success 0.000000 1.000000
# --------------------------------------------------------------------
# KeyboardInterrupt                  Traceback (most recent call last)
# <ipython-input-4-be9a3a5ececb> in <module>()
#       2                         sample_size=20, delta=0.01, step_adapt=2.0/3, epsilon=0.01)
#       3 for i in range(50):
# ----> 4     x_adv = attack.generate(np.array([target_image]))
#       5
#       6     clear_output()
#
# /Users/minhtn/ibm/projects/nemesis/art/attacks/boundary.py in generate(self, x, y)
#     108                 x_ = self._perturb(x=val, y=y[ind], y_p=preds[ind], init_pred=init_pred)
#     109             else:
# --> 110                 x_ = self._perturb(x=val, y=None, y_p=preds[ind], init_pred=init_pred)
#     111
#     112             x_adv[ind] = x_
#
# /Users/minhtn/ibm/projects/nemesis/art/attacks/boundary.py in _perturb(self, x, y, y_p, init_pred)
#     142             x_adv = self._attack(initial_sample, x, y, self.delta, self.epsilon)
#     143         else:
# --> 144             x_adv = self._attack(initial_sample, x, y_p, self.delta, self.epsilon)
#     145
#     146         return x_adv
#
# /Users/minhtn/ibm/projects/nemesis/art/attacks/boundary.py in _attack(self, initial_sample, original_sample, target, initial_delta, initial_epsilon)
#     180                     potential_advs.append(potential_adv)
#     181
# --> 182                 preds = np.argmax(self.classifier.predict(np.array(potential_advs)), axis=1)
#     183
#     184                 if self.targeted:
#
# /Users/minhtn/ibm/projects/nemesis/art/classifiers/keras.py in predict(self, x, logits, batch_size)
#     270         for batch_index in range(int(np.ceil(x_preproc.shape[0] / float(batch_size)))):
#     271             begin, end = batch_index * batch_size, min((batch_index + 1) * batch_size, x_preproc.shape[0])
# --> 272             preds[begin:end] = self._preds([x_preproc[begin:end]])[0]
#     273
#     274             if not logits and not self._custom_activation:
#
# /Users/minhtn/ibm/installation/miniconda3/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# /Users/minhtn/ibm/installation/miniconda3/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# /Users/minhtn/ibm/installation/miniconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/minhtn/ibm/installation/miniconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /Users/minhtn/ibm/installation/miniconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /Users/minhtn/ibm/installation/miniconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /Users/minhtn/ibm/installation/miniconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
13952.328
