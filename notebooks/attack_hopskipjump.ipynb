# %% [markdown]
# # ART HopSkipJump Attack

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import sys
# !{sys.executable} -m pip install git+https://github.com/nottombrown/imagenet_stubs
sys.path.append("..")

# %matplotlib inline

import imagenet_stubs
import numpy as np
import keras
from keras.preprocessing import image
from keras.applications.resnet50 import ResNet50, preprocess_input
from keras.layers import Dense, Flatten
from keras.models import Model
import keras.backend as k
from matplotlib import pyplot as plt
from IPython.display import clear_output

from art.estimators.classification import KerasClassifier
from art.attacks.evasion import HopSkipJump
from art.utils import to_categorical
# Out:
# Collecting git+https://github.com/nottombrown/imagenet_stubs
#   Cloning https://github.com/nottombrown/imagenet_stubs to /tmp/pip-req-build-jueu7ktu
#   Running command git clone -q https://github.com/nottombrown/imagenet_stubs /tmp/pip-req-build-jueu7ktu
# Requirement already satisfied (use --upgrade to upgrade): imagenet-stubs==0.0.7 from git+https://github.com/nottombrown/imagenet_stubs in /home/beat/codes/anaconda3/envs/py37_tf220/lib/python3.7/site-packages
# Building wheels for collected packages: imagenet-stubs
#   Building wheel for imagenet-stubs (setup.py) ... done
#   Created wheel for imagenet-stubs: filename=imagenet_stubs-0.0.7-py3-none-any.whl size=794838 sha256=001020c730a0ac6788b907cc139b1f8b70df0db8e238b71b87c187c824546085
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eo7037v2/wheels/33/0f/5a/c83688c23a05eb9e88527a8944da56dbe007c86f534b0c1dad
# Successfully built imagenet-stubs
# Using TensorFlow backend.

# %% [markdown]
# # Model Definition

# %%
mean_imagenet = np.zeros([224, 224, 3])
mean_imagenet[...,0].fill(103.939)
mean_imagenet[...,1].fill(116.779)
mean_imagenet[...,2].fill(123.68)
model = ResNet50(weights='imagenet')
classifier = KerasClassifier(clip_values=(0, 255), model=model, preprocessing=(mean_imagenet, 1))

# %% [markdown]
# # Get Target and Init Images

# %%
target_image_name = 'koala.jpg'
init_image_name = 'tractor.jpg'
for image_path in imagenet_stubs.get_image_paths():
    if image_path.endswith(target_image_name):
        target_image = image.load_img(image_path, target_size=(224, 224))
        target_image = image.img_to_array(target_image)
    if image_path.endswith(init_image_name):
        init_image = image.load_img(image_path, target_size=(224, 224))
        init_image = image.img_to_array(init_image)

print("Target image is: ", np.argmax(classifier.predict(np.array([target_image]))[0]))
plt.imshow(target_image.astype(np.uint))
plt.show()
print("Init image is: ", np.argmax(classifier.predict(np.array([init_image]))[0]))
plt.imshow(init_image.astype(np.uint))
plt.show()
# Out:
# Target image is:  105
# Init image is:  866

# %% [markdown]
# # HopSkipJump Untargeted Attack

# %%
attack = HopSkipJump(classifier=classifier, targeted=False, max_iter=0, max_eval=1000, init_eval=10)
iter_step = 10
x_adv = None
for i in range(20):
    x_adv = attack.generate(x=np.array([target_image]), x_adv_init=x_adv, resume=True)

    #clear_output()
    print("Adversarial image at step %d." % (i * iter_step), "L2 error", 
          np.linalg.norm(np.reshape(x_adv[0] - target_image, [-1])),
          "and class label %d." % np.argmax(classifier.predict(x_adv)[0]))
    plt.imshow(x_adv[0].astype(np.uint))
    plt.show(block=False)
    
    attack.max_iter = iter_step
# Out:
# HopSkipJump: 100%|██████████| 1/1 [00:00<00:00,  6.06it/s]
# Adversarial image at step 0. L2 error 15122.422 and class label 678.
# HopSkipJump: 100%|██████████| 1/1 [00:08<00:00,  8.19s/it]
# Adversarial image at step 10. L2 error 8226.08 and class label 359.
# HopSkipJump: 100%|██████████| 1/1 [00:12<00:00, 12.02s/it]
# Adversarial image at step 20. L2 error 5718.758 and class label 359.
# HopSkipJump: 100%|██████████| 1/1 [00:15<00:00, 15.10s/it]
# Adversarial image at step 30. L2 error 4529.9414 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:17<00:00, 17.69s/it]
# Adversarial image at step 40. L2 error 3536.3748 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:18<00:00, 18.89s/it]
# Adversarial image at step 50. L2 error 2844.8 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:20<00:00, 20.94s/it]
# Adversarial image at step 60. L2 error 2363.162 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:22<00:00, 22.35s/it]
# Adversarial image at step 70. L2 error 1952.3788 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:23<00:00, 23.64s/it]
# Adversarial image at step 80. L2 error 1641.5048 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:25<00:00, 25.20s/it]
# Adversarial image at step 90. L2 error 1420.2499 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:26<00:00, 26.07s/it]
# Adversarial image at step 100. L2 error 1245.6654 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:27<00:00, 27.12s/it]
# Adversarial image at step 110. L2 error 1106.456 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:28<00:00, 28.59s/it]
# Adversarial image at step 120. L2 error 1001.6793 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:28<00:00, 28.84s/it]
# Adversarial image at step 130. L2 error 917.5385 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:29<00:00, 29.85s/it]
# Adversarial image at step 140. L2 error 845.7709 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:31<00:00, 31.72s/it]
# Adversarial image at step 150. L2 error 782.34424 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:32<00:00, 32.66s/it]
# Adversarial image at step 160. L2 error 726.9867 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:32<00:00, 32.66s/it]
# Adversarial image at step 170. L2 error 682.7859 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:34<00:00, 34.38s/it]
# Adversarial image at step 180. L2 error 639.8016 and class label 356.
# HopSkipJump: 100%|██████████| 1/1 [00:33<00:00, 33.59s/it]
# Adversarial image at step 190. L2 error 602.64813 and class label 356.

# %% [markdown]
# # HopSkipJump Targeted Attack

# %%
attack = HopSkipJump(classifier=classifier, targeted=True, max_iter=0, max_eval=1000, init_eval=10)
iter_step = 10
x_adv = np.array([init_image])
for i in range(20):
    x_adv = attack.generate(x=np.array([target_image]), y=to_categorical([866], 1000), x_adv_init=x_adv, resume=True)

    #clear_output()
    print("Adversarial image at step %d." % (i * iter_step), "L2 error", 
          np.linalg.norm(np.reshape(x_adv[0] - target_image, [-1])),
          "and class label %d." % np.argmax(classifier.predict(x_adv)[0]))
    plt.imshow(x_adv[0].astype(np.uint))
    plt.show(block=False)
    
    attack.max_iter = iter_step
# Out:
# HopSkipJump: 100%|██████████| 1/1 [00:00<00:00, 1646.12it/s]
# Adversarial image at step 0. L2 error 44400.055 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:07<00:00,  7.49s/it]
# Adversarial image at step 10. L2 error 16090.395 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:11<00:00, 11.11s/it]
# Adversarial image at step 20. L2 error 13582.757 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:12<00:00, 12.83s/it]
# Adversarial image at step 30. L2 error 11330.058 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:15<00:00, 15.70s/it]
# Adversarial image at step 40. L2 error 9441.322 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:17<00:00, 17.52s/it]
# Adversarial image at step 50. L2 error 8609.562 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:18<00:00, 18.79s/it]
# Adversarial image at step 60. L2 error 7154.442 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:21<00:00, 21.02s/it]
# Adversarial image at step 70. L2 error 6241.058 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:21<00:00, 21.54s/it]
# Adversarial image at step 80. L2 error 5354.433 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:23<00:00, 23.44s/it]
# Adversarial image at step 90. L2 error 4786.8726 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:25<00:00, 25.16s/it]
# Adversarial image at step 100. L2 error 4261.8384 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:25<00:00, 25.93s/it]
# Adversarial image at step 110. L2 error 3774.0457 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:27<00:00, 27.42s/it]
# Adversarial image at step 120. L2 error 3499.7463 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:27<00:00, 27.94s/it]
# Adversarial image at step 130. L2 error 3105.673 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:28<00:00, 28.45s/it]
# Adversarial image at step 140. L2 error 2892.3452 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:28<00:00, 28.47s/it]
# Adversarial image at step 150. L2 error 2632.5198 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:28<00:00, 28.71s/it]
# Adversarial image at step 160. L2 error 2408.4705 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:31<00:00, 31.55s/it]
# Adversarial image at step 170. L2 error 2237.9478 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:33<00:00, 33.69s/it]
# Adversarial image at step 180. L2 error 2083.3662 and class label 866.
# HopSkipJump: 100%|██████████| 1/1 [00:33<00:00, 33.17s/it]
# Adversarial image at step 190. L2 error 1958.5798 and class label 866.

# %% [markdown]
# # Unsquared Images

# %% [markdown]
# HopSkipJump attack supports inputs of unsquared images. The code in the following cell describes an example of creating a Resnet50-based classifier to attack unsquared images.

# %% [markdown]
# ```python
# # Adjust image shape here
# image_shape = (224, 150)
#
# mean_imagenet = np.zeros(tuple(list(image_shape) + [3]))
# mean_imagenet[...,0].fill(103.939)
# mean_imagenet[...,1].fill(116.779)
# mean_imagenet[...,2].fill(123.68)
#
# model = ResNet50(weights='imagenet', input_shape=tuple(list(image_shape) + [3]), include_top=False)
#
# def _kr_initialize(_, dtype=None):
#     return k.variable(value=np.random.randn(np.prod(list(model.output.shape)[1:]).value, 1000))
#
# head = model.output
# head = Flatten()(head)
# head = Dense(1000, kernel_initializer=_kr_initialize, bias_initializer=keras.initializers.Zeros())(head)
# new_model = Model(inputs=model.input, outputs=head)
#
# classifier = KerasClassifier(clip_values=(0, 255), model=new_model, preprocessing=(mean_imagenet, 1))
# # Then call classifier.fit() to train the new weights
# ```
